# %%
array = ["水","金","地","火","木","土","天","海","冥"]

# forループ
for planet in array:
    print(planet)

# whileループ
while array:
    planet = array.pop(0)
    print(planet)
# Out:
# 水
# 金
# 地
# 火
# 木
# 土
# 天
# 海
# 冥
# 水
# 金
# 地
# 火
# 木
# 土
# 天
# 海
# 冥
